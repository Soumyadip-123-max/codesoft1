# %%
class ATM:
    def __init__(self, balance=0):
        self.balance = balance

    def check_balance(self):
        print(f"Current Balance: ₹{self.balance}")

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"₹{amount} deposited successfully.")
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount.")
        elif amount > self.balance:
            print("Insufficient balance.")
        else:
            self.balance -= amount
            print(f"₹{amount} withdrawn successfully.")

# Example usage
atm = ATM(1000)  # Starting balance ₹1000
atm.check_balance()
atm.deposit(500)
atm.withdraw(200)
atm.check_balance()
# Out:
# Current Balance: ₹1000
# ₹500 deposited successfully.
# ₹200 withdrawn successfully.
# Current Balance: ₹1300

# %%
class ATM:
    def __init__(self, balance=0):
        self.balance = balance

    def check_balance(self):
        print(f"\n💰 Current Balance: ₹{self.balance}")

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"\n✅ ₹{amount} deposited successfully.")
        else:
            print("\n❌ Invalid deposit amount.")

    def withdraw(self, amount):
        if amount <= 0:
            print("\n❌ Invalid withdrawal amount.")
        elif amount > self.balance:
            print("\n⚠️ Insufficient balance.")
        else:
            self.balance -= amount
            print(f"\n✅ ₹{amount} withdrawn successfully.")


# Interactive ATM Interface
def atm_interface():
    atm = ATM(1000)  # Starting balance ₹1000

    while True:
        print("\n===== 🏦 ATM MENU =====")
        print("1. Withdraw Money")
        print("2. Deposit Money")
        print("3. Check Balance")
        print("4. Exit")
        choice = input("Select an option (1-4): ")

        if choice == "1":
            try:
                amount = float(input("Enter withdrawal amount: ₹"))
                atm.withdraw(amount)
            except ValueError:
                print("\n❌ Please enter a valid number.")

        elif choice == "2":
            try:
                amount = float(input("Enter deposit amount: ₹"))
                atm.deposit(amount)
            except ValueError:
                print("\n❌ Please enter a valid number.")

        elif choice == "3":
            atm.check_balance()

        elif choice == "4":
            print("\n💳 Thank you for using the ATM. Goodbye!")
            break

        else:
            print("\n❌ Invalid choice. Please select 1-4.")


# Run the ATM
atm_interface()
# Out:
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 2
# Enter deposit amount: ₹1000
#
# ✅ ₹1000.0 deposited successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 1
# Enter withdrawal amount: ₹5000
#
# ⚠️ Insufficient balance.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 3
#
# 💰 Current Balance: ₹2000.0
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 4
#
# 💳 Thank you for using the ATM. Goodbye!

# %%
class ATM:
    def __init__(self, balance=0):
        self.balance = balance

    def withdraw(self, amount):
        """Withdraw the given amount if sufficient balance exists."""
        if amount <= 0:
            print("\n❌ Invalid withdrawal amount.")
        elif amount > self.balance:
            print("\n⚠️ Insufficient balance.")
        else:
            self.balance -= amount
            print(f"\n✅ ₹{amount} withdrawn successfully.")

    def deposit(self, amount):
        """Deposit the given amount into the account."""
        if amount > 0:
            self.balance += amount
            print(f"\n✅ ₹{amount} deposited successfully.")
        else:
            print("\n❌ Invalid deposit amount.")

    def check_balance(self):
        """Display the current balance."""
        print(f"\n💰 Current Balance: ₹{self.balance}")

    def menu(self):
        """Display the ATM menu and handle user choices."""
        while True:
            print("\n===== 🏦 ATM MENU =====")
            print("1. Withdraw Money")
            print("2. Deposit Money")
            print("3. Check Balance")
            print("4. Exit")
            choice = input("Select an option (1-4): ")

            if choice == "1":
                try:
                    amount = float(input("Enter withdrawal amount: ₹"))
                    self.withdraw(amount)
                except ValueError:
                    print("\n❌ Please enter a valid number.")

            elif choice == "2":
                try:
                    amount = float(input("Enter deposit amount: ₹"))
                    self.deposit(amount)
                except ValueError:
                    print("\n❌ Please enter a valid number.")

            elif choice == "3":
                self.check_balance()

            elif choice == "4":
                print("\n💳 Thank you for using the ATM. Goodbye!")
                break

            else:
                print("\n❌ Invalid choice. Please select 1-4.")


# Create an ATM object with starting balance ₹1000 and start the menu
atm = ATM(1000)
atm.menu()
# Out:
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 1
# Enter withdrawal amount: ₹1500
#
# ⚠️ Insufficient balance.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 2
# Enter deposit amount: ₹5000
#
# ✅ ₹5000.0 deposited successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 3
#
# 💰 Current Balance: ₹6000.0
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 4
#
# 💳 Thank you for using the ATM. Goodbye!

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        """Deposit the given amount into the account."""
        if amount > 0:
            self.balance += amount
            print(f"\n✅ ₹{amount} deposited successfully.")
        else:
            print("\n❌ Deposit amount must be positive.")

    def withdraw(self, amount):
        """Withdraw the given amount if sufficient balance exists."""
        if amount <= 0:
            print("\n❌ Withdrawal amount must be positive.")
        elif amount > self.balance:
            print("\n⚠️ Insufficient balance.")
        else:
            self.balance -= amount
            print(f"\n✅ ₹{amount} withdrawn successfully.")

    def get_balance(self):
        """Return the current account balance."""
        return self.balance

    def display_balance(self):
        """Print the current balance."""
        print(f"\n💰 Current Balance: ₹{self.balance}")


# Example usage
account = BankAccount("Soumyadip Bhunia", 5000)  # Starting with ₹5000
account.display_balance()
account.deposit(2000)
account.withdraw(1500)
account.display_balance()
# Out:
# 💰 Current Balance: ₹5000
#
# ✅ ₹2000 deposited successfully.
#
# ✅ ₹1500 withdrawn successfully.
#
# 💰 Current Balance: ₹5500

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"\n✅ ₹{amount} deposited successfully.")
        else:
            print("\n❌ Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount <= 0:
            print("\n❌ Withdrawal amount must be positive.")
        elif amount > self.balance:
            print("\n⚠️ Insufficient balance.")
        else:
            self.balance -= amount
            print(f"\n✅ ₹{amount} withdrawn successfully.")

    def get_balance(self):
        return self.balance

    def display_balance(self):
        print(f"\n💰 Current Balance: ₹{self.balance}")


class ATM:
    def __init__(self, bank_account):
        self.bank_account = bank_account  # Link to BankAccount

    def menu(self):
        while True:
            print("\n===== 🏦 ATM MENU =====")
            print("1. Withdraw Money")
            print("2. Deposit Money")
            print("3. Check Balance")
            print("4. Exit")
            choice = input("Select an option (1-4): ")

            if choice == "1":
                try:
                    amount = float(input("Enter withdrawal amount: ₹"))
                    self.bank_account.withdraw(amount)
                except ValueError:
                    print("\n❌ Please enter a valid number.")

            elif choice == "2":
                try:
                    amount = float(input("Enter deposit amount: ₹"))
                    self.bank_account.deposit(amount)
                except ValueError:
                    print("\n❌ Please enter a valid number.")

            elif choice == "3":
                self.bank_account.display_balance()

            elif choice == "4":
                print("\n💳 Thank you for using the ATM. Goodbye!")
                break

            else:
                print("\n❌ Invalid choice. Please select 1-4.")


# Create a bank account for the user
user_account = BankAccount("Soumyadip Bhunia", 5000)

# Create an ATM linked to the user's bank account
atm_machine = ATM(user_account)

# Start the ATM interface
atm_machine.menu()
# Out:
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 1
# Enter withdrawal amount: ₹1000
#
# ✅ ₹1000.0 withdrawn successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 2
# Enter deposit amount: ₹2500
#
# ✅ ₹2500.0 deposited successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 3
#
# 💰 Current Balance: ₹6500.0
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 4
#
# 💳 Thank you for using the ATM. Goodbye!

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            print("\n❌ Deposit amount must be positive.")
        elif amount > 50000:
            print("\n⚠️ Deposit limit exceeded! Maximum ₹50,000 per transaction.")
        else:
            self.balance += amount
            print(f"\n✅ ₹{amount} deposited successfully.")

    def withdraw(self, amount):
        if amount <= 0:
            print("\n❌ Withdrawal amount must be positive.")
        elif amount > 20000:
            print("\n⚠️ Withdrawal limit exceeded! Maximum ₹20,000 per transaction.")
        elif amount > self.balance:
            print("\n⚠️ Insufficient balance.")
        else:
            self.balance -= amount
            print(f"\n✅ ₹{amount} withdrawn successfully.")

    def display_balance(self):
        print(f"\n💰 Current Balance: ₹{self.balance}")


class ATM:
    def __init__(self, bank_account):
        self.bank_account = bank_account

    def get_valid_amount(self, prompt):
        """Ensure user enters a valid positive numeric value."""
        while True:
            try:
                amount = float(input(prompt))
                if amount <= 0:
                    print("\n❌ Please enter a positive amount.")
                else:
                    return amount
            except ValueError:
                print("\n❌ Invalid input. Please enter a number.")

    def menu(self):
        while True:
            print("\n===== 🏦 ATM MENU =====")
            print("1. Withdraw Money")
            print("2. Deposit Money")
            print("3. Check Balance")
            print("4. Exit")
            choice = input("Select an option (1-4): ")

            if choice == "1":
                amount = self.get_valid_amount("Enter withdrawal amount: ₹")
                self.bank_account.withdraw(amount)

            elif choice == "2":
                amount = self.get_valid_amount("Enter deposit amount: ₹")
                self.bank_account.deposit(amount)

            elif choice == "3":
                self.bank_account.display_balance()

            elif choice == "4":
                print("\n💳 Thank you for using the ATM. Goodbye!")
                break

            else:
                print("\n❌ Invalid choice. Please select 1-4.")


# Example usage
user_account = BankAccount("Soumyadip Bhunia", 5000)
atm_machine = ATM(user_account)
atm_machine.menu()
# Out:
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 1
# Enter withdrawal amount: ₹1375
#
# ✅ ₹1375.0 withdrawn successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 2
# Enter deposit amount: ₹3000
#
# ✅ ₹3000.0 deposited successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 3
#
# 💰 Current Balance: ₹6625.0
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 4
#
# 💳 Thank you for using the ATM. Goodbye!

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            return "❌ Deposit amount must be positive."
        elif amount > 50000:
            return "⚠️ Deposit limit exceeded! Maximum ₹50,000 per transaction."
        else:
            self.balance += amount
            return f"✅ ₹{amount} deposited successfully."

    def withdraw(self, amount):
        if amount <= 0:
            return "❌ Withdrawal amount must be positive."
        elif amount > 20000:
            return "⚠️ Withdrawal limit exceeded! Maximum ₹20,000 per transaction."
        elif amount > self.balance:
            return "⚠️ Insufficient balance."
        else:
            self.balance -= amount
            return f"✅ ₹{amount} withdrawn successfully."

    def display_balance(self):
        return f"💰 Current Balance: ₹{self.balance}"


class ATM:
    def __init__(self, bank_account):
        self.bank_account = bank_account

    def get_valid_amount(self, prompt):
        while True:
            try:
                amount = float(input(prompt))
                if amount <= 0:
                    print("❌ Please enter a positive amount.")
                else:
                    return amount
            except ValueError:
                print("❌ Invalid input. Please enter a number.")

    def menu(self):
        while True:
            print("\n===== 🏦 ATM MENU =====")
            print("1. Withdraw Money")
            print("2. Deposit Money")
            print("3. Check Balance")
            print("4. Exit")
            choice = input("Select an option (1-4): ")

            if choice == "1":
                amount = self.get_valid_amount("Enter withdrawal amount: ₹")
                message = self.bank_account.withdraw(amount)
                print(message)

            elif choice == "2":
                amount = self.get_valid_amount("Enter deposit amount: ₹")
                message = self.bank_account.deposit(amount)
                print(message)

            elif choice == "3":
                print(self.bank_account.display_balance())

            elif choice == "4":
                print("\n💳 Thank you for using the ATM. Goodbye!")
                break

            else:
                print("❌ Invalid choice. Please select 1-4.")


# Example usage
user_account = BankAccount("Soumyadip Bhunia", 5000)
atm_machine = ATM(user_account)
atm_machine.menu()
# Out:
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 1
# Enter withdrawal amount: ₹1000
# ✅ ₹1000.0 withdrawn successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 2
# Enter deposit amount: ₹3000
# ✅ ₹3000.0 deposited successfully.
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 3
# 💰 Current Balance: ₹7000.0
#
# ===== 🏦 ATM MENU =====
# 1. Withdraw Money
# 2. Deposit Money
# 3. Check Balance
# 4. Exit
# Select an option (1-4): 4
#
# 💳 Thank you for using the ATM. Goodbye!
